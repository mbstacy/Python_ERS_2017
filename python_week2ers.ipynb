# %% [markdown]
# ## Remote Sensing Data Examples
#
# This section will start to work with remote sensing data. The data will be loaded into python pandas dataframe and graphs and computation will be performed.

# %%
import pandas as pd

# %%
# modis file downloaded from http://www.eomf.ou.edu/modis/visualization/ 
# single site time series.
data =pd.read_csv('modis/mod09a1_lat_46.746525_lon_-101.489012_years_2013,2014,2015,2016.csv',
                  na_values=['NA','Na'])

# %%
# convert Date field to datetime data type
data['Date'] = pd.to_datetime(data['Date'])
#Set Index
data = data.set_index(['Date'])

# %%
data.columns
# Out:
# Index(['Surface_reflectance_for_band_1', 'Surface_reflectance_for_band_2',
#        'Surface_reflectance_for_band_3', 'Surface_reflectance_for_band_4',
#        'Surface_reflectance_for_band_5', 'Surface_reflectance_for_band_6',
#        'Surface_reflectance_for_band_7',
#        'Surface_reflectance_500m_quality_control_flags', 'Solar_zenith',
#        'View_zenith', 'Relative_azimuth',
#        'Surface_reflectance_500m_state_flags',
#        'Surface_reflectance_day_of_year', 'actual_date', 'red', 'nir1', 'blue',
#        'green', 'nir2', 'swir1', 'swir2', 'NDVI', 'EVI', 'LSWI', 'LSWI2105',
#        'NDSI', 'NDWI1200', 'sur_refl_state_500m (binary)', 'MOD35 cloud',
#        'cloud shadow', 'land/water flag', 'aerosol quantity',
#        'cirrus detected', 'internal cloud algorithm flag',
#        'internal fire algorithm flag', 'MOD35 snow/ice flag',
#        'Pixel is adjacent to cloud', 'BRDF correction performed',
# ...

# %%
# Jupyter Notebook inline plots
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data.ix[:,'NDVI':'EVI'].plot()

# %% [markdown]
# ## Remote sensing Data
#
# Load data into Pandas Dataframe!!

# %%
#Reflectance data
rf_data = pd.read_csv('modis/US-Ha1-MODIS.csv')
#flux data
flux_data = pd.read_csv('modis/US-Ha1-Flux.csv')
flux_data
# Out:
#       Unnamed: 0     time  Ta_min (Deg C)  Ta_max (Deg C)  Ta_mean (Deg C)  \
# 0              1  1991001         -12.516           5.659        -2.133052
# 1              2  1991009          -9.628           5.606        -2.076333
# 2              3  1991017         -15.015           3.803        -2.916281
# 3              4  1991025          -8.401           6.114         0.754693
# 4              5  1991033          -8.296           5.857         0.262516
# 5              6  1991041         -18.097           2.769        -4.903281
# 6              7  1991049         -17.068          11.757         0.549958
# 7              8  1991057          -7.127          11.804         1.122495
# 8              9  1991065          -4.579           8.302         0.756693
# 9             10  1991073          -2.028          13.493         4.404802
# 10            11  1991081          -1.974          16.737         5.845464
# ...

# %% [markdown]
# ### Convert string of Year and Day of Year to datetime

# %%
# Convert 'YYYYdoy' to date data type 
flux_data['date']=pd.to_datetime(flux_data['time'],format='%Y%j')
flux_data.index = flux_data['date']

# %%
flux_data= flux_data.ix[:,'time':]
flux_data
# Out:
#                time  Ta_min (Deg C)  Ta_max (Deg C)  Ta_mean (Deg C)  \
# date
# 1991-01-01  1991001         -12.516           5.659        -2.133052
# 1991-01-09  1991009          -9.628           5.606        -2.076333
# 1991-01-17  1991017         -15.015           3.803        -2.916281
# 1991-01-25  1991025          -8.401           6.114         0.754693
# 1991-02-02  1991033          -8.296           5.857         0.262516
# 1991-02-10  1991041         -18.097           2.769        -4.903281
# 1991-02-18  1991049         -17.068          11.757         0.549958
# 1991-02-26  1991057          -7.127          11.804         1.122495
# 1991-03-06  1991065          -4.579           8.302         0.756693
# 1991-03-14  1991073          -2.028          13.493         4.404802
# 1991-03-22  1991081          -1.974          16.737         5.845464
# 1991-03-30  1991089           1.625          17.375         9.734964
# ...

# %% [markdown]
# ### Plot data with matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
plt.figure(figsize=(20,5))
plt.xticks(rotation=80)

ax =plt.plot(flux_data.date, flux_data['Ta_max (Deg C)'],'g-')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y'))
plt.show()

# %% [markdown]
# ## Slice Dataframe
#
# Set title and labels for both axes.

# %%
ta = flux_data.ix['2000-01-01':,'Ta_min (Deg C)':'Ta_nighttime_mean(Deg C)']
ta['Date']= rf_data['Date']
ta
# Out:
#             Ta_min (Deg C)  Ta_max (Deg C)  Ta_mean (Deg C)  \
# date
# 2000-01-01          -6.000          12.200         3.875458
# 2000-01-09         -12.120          12.000        -3.060214
# 2000-01-17         -10.301           6.854         0.518104
# 2000-01-25          -7.333           6.843         0.528010
# 2000-02-02          -8.173           6.621        -0.388953
# 2000-02-10         -11.474           5.510        -2.211531
# 2000-02-18         -11.771           6.044        -2.554323
# 2000-02-26          -7.673          12.667         4.527682
# 2000-03-05          -4.299          18.300         4.521703
# 2000-03-13         -12.600          17.100         0.504167
# 2000-03-21          -1.300          16.101         6.481240
# 2000-03-29          -0.600          14.600         6.392708
# 2000-04-06          -3.600          21.300         4.444792
# 2000-04-14          -0.800          20.400         6.867708
# ...

# %%
# Copied code from above -- This should give you a hint to make this into a funciton
plt.figure(figsize=(20,5))
plt.xticks(rotation=90)
plt.title("Daily Maximum Temperature")
plt.ylabel("Max Temp (Deg C)")
plt.xlabel("Date")
#ta['Ta_min (Deg C)'.plot()
ax =plt.plot(ta.index, ta['Ta_max (Deg C)'],'g-')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.show()

# %%
# Copied code from above -- This should give you a hint to make this into a funciton
# Set figure
plt.figure(figsize=(20,5))
plt.xticks(rotation=45)
plt.plot(ta.index, ta['Ta_min (Deg C)'],'g-')
plt.title('Minimum Temperature')
plt.xlabel("Date")
plt.ylabel("Temperature (Deg C)")
# set xaxis major Dateformater
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
# set grid lines
ax1 = plt.gca()
ax1.grid(True)
plt.show()

# %% [markdown]
# ## RF Data

# %%
rf_data = pd.read_csv('modis/US-Ha1-MODIS.csv',na_values=['NA','na'])

# %%
# convert to date time data type and set index
rf_data['Date']=pd.to_datetime(rf_data['Date'],format='%m/%d/%Y')
rf_data.index = rf_data['Date']
#rf_data.index
rf_data
# Out:
#                  Date  Surface_reflectance_for_band_1  \
# Date
# 2016-01-01 2016-01-01                           232.0
# 2016-01-09 2016-01-09                           148.0
# 2016-01-17 2016-01-17                           447.0
# 2016-01-25 2016-01-25                           148.0
# 2016-02-02 2016-02-02                           626.0
# 2016-02-10 2016-02-10                           445.0
# 2016-02-18 2016-02-18                             NaN
# 2016-02-26 2016-02-26                          1369.0
# 2016-03-05 2016-03-05                           440.0
# 2016-03-13 2016-03-13                           490.0
# 2016-03-21 2016-03-21                           479.0
# 2016-03-29 2016-03-29                           638.0
# 2016-04-06 2016-04-06                           553.0
# 2016-04-14 2016-04-14                           554.0
# 2016-04-22 2016-04-22                           397.0
# 2016-04-30 2016-04-30                             NaN
# ...

# %%
# Copied code from above -- This should give you a hint to make this into a funciton
plt.figure(figsize=(20,5))
plt.xticks(rotation=90)
plt.plot(rf_data.index, rf_data['GF_NDVI'],'b-')
plt.title('GF NDVI')
plt.xlabel("Date")
plt.ylabel("NDVI")
# set xaxis major Dateformater
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
# set grid lines
ax1 = plt.gca()
ax1.grid(True)
plt.show()

# %% [markdown]
# ### Create Function to plot data
#
# 1. Create plot and export out to file

# %%
def myplot(x,y,style,title,xlabel,ylabel,figsize=(20,5),filename="test.png"):
    fig, axes = plt.subplots()
    ax=y.plot(ax=axes,figsize=figsize,title=title,style=style)
    plt.xticks(rotation=90)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    # set xaxis major Dateformater
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    # set grid lines
    ax = plt.gca().grid(True)
    fig.savefig(filename,dpi=300, bbox_inches='tight')

# %%
x=rf_data.index
y= rf_data.ix[:,'GF_NDVI':'GF_EVI']
myplot(x,y ,'',"Vegitation Index","Date","Vegitation Index",
       figsize=(20,10),
      filename="test.jpg")

# %%
# create a subset of data just Vegitation Index
rf_subset= rf_data[['GF_NDVI','GF_EVI']]

# %%
rf_subset.index= rf_data.Date
rf_subset
# Out:
#              GF_NDVI    GF_EVI
# Date
# 2016-01-01  0.761562  0.288979
# 2016-01-09  0.695073  0.291846
# 2016-01-17  0.628583  0.294713
# 2016-01-25  0.618176  0.318137
# 2016-02-02  0.607769  0.341561
# 2016-02-10  0.361091  0.120734
# 2016-02-18       NaN       NaN
# 2016-02-26  0.236688  0.190410
# 2016-03-05  0.619870  0.275326
# 2016-03-13  0.574283  0.258012
# 2016-03-21  0.610411  0.286472
# 2016-03-29  0.595434  0.343918
# 2016-04-06  0.592333  0.297637
# 2016-04-14  0.602011  0.309020
# 2016-04-22  0.628277  0.265669
# 2016-04-30       NaN       NaN
# 2016-05-08       NaN       NaN
# 2016-05-16       NaN       NaN
# 2016-05-24       NaN       NaN
# 2016-06-01       NaN       NaN
# 2016-06-09       NaN       NaN
# 2016-06-17       NaN       NaN
# 2016-06-25       NaN       NaN
# 2016-07-03       NaN       NaN
# 2016-07-11       NaN       NaN
# 2016-07-19       NaN       NaN
# 2016-07-27       NaN       NaN
# 2016-08-04       NaN       NaN
# 2016-08-12       NaN       NaN
# ...

# %%
x=rf_data.index
y=rf_subset
myplot(x,y,'',"Vegitation Index","Date","Vegitation Index",figsize=(20,5))

# %% [markdown]
# ## Pandas apply

# %%
def vi_classification(exp):
    if exp < 0.25:
        # This observation is low 
        return "Low VI"
    elif exp >= 0.25 and exp<= 0.75:
        # This observation is Mid Range
        return "Mid Range VI"
    elif exp >= 0.75:
        # This observation is High Range
        return "High Range VI"
    else:
        # This observation has bad data
        return "NA"
    #return "NA"

# %%
rf_subset.columns
# Out:
# Index(['GF_NDVI', 'GF_EVI'], dtype='object')

# %%
rf_subset['VI_Classification']=rf_subset['GF_NDVI'].apply(vi_classification)
# Out:
# /Users/mstacy/anaconda36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
rf_subset
# Out:
#              GF_NDVI    GF_EVI VI_Classification
# Date
# 2016-01-01  0.761562  0.288979     High Range VI
# 2016-01-09  0.695073  0.291846      Mid Range VI
# 2016-01-17  0.628583  0.294713      Mid Range VI
# 2016-01-25  0.618176  0.318137      Mid Range VI
# 2016-02-02  0.607769  0.341561      Mid Range VI
# 2016-02-10  0.361091  0.120734      Mid Range VI
# 2016-02-18       NaN       NaN                NA
# 2016-02-26  0.236688  0.190410            Low VI
# 2016-03-05  0.619870  0.275326      Mid Range VI
# 2016-03-13  0.574283  0.258012      Mid Range VI
# 2016-03-21  0.610411  0.286472      Mid Range VI
# 2016-03-29  0.595434  0.343918      Mid Range VI
# 2016-04-06  0.592333  0.297637      Mid Range VI
# 2016-04-14  0.602011  0.309020      Mid Range VI
# 2016-04-22  0.628277  0.265669      Mid Range VI
# 2016-04-30       NaN       NaN                NA
# 2016-05-08       NaN       NaN                NA
# 2016-05-16       NaN       NaN                NA
# ...

# %% [markdown]
# ### Row level apply function
#
#
# Send entire row to the function.

# %%
def vi_classification_row(dr):
    if dr['GF_NDVI'] >0.5 and dr['GF_EVI']<0.5:
        return "Set1"
    else:
        try:
            result = dr['GF_NDVI'] * dr['GF_EVI']
        except:
            result = None
        return result

# %%
rf_subset['set']=rf_subset.apply(vi_classification_row,axis=1)
# Out:
# /Users/mstacy/anaconda36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
rf_subset
# Out:
#              GF_NDVI    GF_EVI VI_Classification  great        set
# Date
# 2016-01-01  0.761562  0.288979     High Range VI  great       Set1
# 2016-01-09  0.695073  0.291846      Mid Range VI  great       Set1
# 2016-01-17  0.628583  0.294713      Mid Range VI  great       Set1
# 2016-01-25  0.618176  0.318137      Mid Range VI  great       Set1
# 2016-02-02  0.607769  0.341561      Mid Range VI  great       Set1
# 2016-02-10  0.361091  0.120734      Mid Range VI  great  0.0435958
# 2016-02-18       NaN       NaN                NA  great        NaN
# 2016-02-26  0.236688  0.190410            Low VI  great  0.0450678
# 2016-03-05  0.619870  0.275326      Mid Range VI  great       Set1
# 2016-03-13  0.574283  0.258012      Mid Range VI  great       Set1
# 2016-03-21  0.610411  0.286472      Mid Range VI  great       Set1
# 2016-03-29  0.595434  0.343918      Mid Range VI  great       Set1
# 2016-04-06  0.592333  0.297637      Mid Range VI  great       Set1
# ...

# %%
myplot(rf_data.index, rf_data['GF_NDVI'],'g-',"NDVI","Date","NDVI")

# %% [markdown]
# ### Pandas merge dataframes together

# %%
mergedataframe = rf_subset.merge(flux_data,left_index=True,right_index=True)
y=mdf[['GF_NDVI','GF_EVI','Ta_min (Deg C)','Ta_max (Deg C)']]
mdf["Date"]= mdf.index
myplot(mdf.Date,y,'','Temperature and EVI','Date','Deg C')

# %% [markdown]
# ### Chart with multiple y axis
#
# Example Code: http://matplotlib.org/examples/api/two_scales.html

# %%
#Create chart with multiple y axis
fig, ax1 = plt.subplots()
t = mdf.Date
s1 = mdf[['GF_EVI']]
ax1.plot(t, s1, 'b--')
ax1.set_xlabel('Date')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Vegitation Iindex', color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
s2 =mdf[['Ta_max (Deg C)']]
ax2.plot(t, s2, 'g-')
ax2.set_ylabel('Temp Deg C', color='g')
ax2.tick_params('y', colors='g')
fig.tight_layout()
#plt.figure(figsize=(10,15))
plt.show()

# %% [markdown]
# ### Pandas Group By

# %%
grouped = mdf.groupby([mdf['Date'].map(lambda x: x.year) ,mdf['Date'].map(lambda x: x.month),])
grouped['Ta_mean (Deg C)'].agg(['min','mean','max','std','size'])
#mdf
# Out:
#                  min       mean        max       std  size
# Date Date
# 2000 2      4.527682   4.527682   4.527682       NaN     1
#      3      0.504167   4.474954   6.481240  2.797159     4
#      4      4.444792   7.413906  13.704060  4.335119     4
#      5     12.281370  14.265510  17.358260  2.713939     3
#      6     14.458940  17.225742  19.405090  2.326978     4
#      7     17.014080  18.156125  19.416670  0.991315     4
#      8     16.169680  17.997808  20.504320  1.830482     4
#      9     11.086980  13.410547  15.678120  2.543950     4
#      10     5.426073   6.941516   8.084896  1.277712     4
#      11    -0.426823   1.757639   5.609375  3.345710     3
#      12    -8.177778  -5.526799  -2.470042  2.346947     4
# 2001 1     -5.130969  -3.916336  -2.226563  1.219171     4
#      2     -5.237958  -3.654923  -1.220651  1.747076     4
#      3     -1.518229   1.291167   4.585245  2.985734     4
#      4      5.885417   9.198968  13.662530  4.014071     3
# ...

# %%
#grp1= grouped['Ta_mean (Deg C)'].agg(['min','mean','max','std','size'])
grp1 = grouped['Ta_min (Deg C)'].mean()
grp1.plot(x='Date',rot=90, title="Monthly Temperature")

# %%
ax = grp1.plot(x='Date',rot=90,kind='bar',title="Air Temperature",figsize=(40,5))
ax.set_ylabel("Celsius")

# %% [markdown]
# ### Export to Script

# %% [markdown]
# We want to export our myplot function to a script.
#
# 1. Copy function and add to .py file
# 2. if __name__ == '__main__': at bottom of script
# 3. sys.argv to collect command line arguments
# 4. $ python filename args
#
# Demonstration of script file!!!!
#
# See below for entire function parts.

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import sys

def myplot(x,y,style,title,xlabel,ylabel,figsize=(20,5),filename="test.png"):
    fig, axes = plt.subplots()
    ax=y.plot(ax=axes,figsize=figsize,title=title,style=style)
    plt.xticks(rotation=90)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    # set xaxis major Dateformater
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    # set grid lines
    ax = plt.gca().grid(True)
    fig.savefig(filename,dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Pandas Oklahoma Mesonet
#
# Pandas lesson:
# http://ouinformatics.github.io/swc_python_pandas/
#
#
# Oklahoma Mesonet Python Library
# https://github.com/mbstacy/okmesonet
#
#     $ pip install https://github.com/mbstacy/okmesonet/zipball/master

# %%
from okmesonet import weather
from datetime import datetime
start_date = datetime(2005,3,1)
end_date = datetime(2005,4,1)

# %%
#Return Mesonet Site Metadata
sites=weather.site_data()
sites
# Out:
#      stnm  stid                 name           city  rang cdir        cnty  \
# 0     110  ACME                 Acme   Rush Springs   4.0  WNW       Grady
# 1       1  ADAX                  Ada            Ada   2.0  NNE    Pontotoc
# 2       2  ALTU                Altus          Altus   3.0    S     Jackson
# 3     116  ALV2                 Alva           Alva   7.2  SSW       Woods
# 4       3  ALVA                 Alva           Alva   2.0    S       Woods
# 5     135  ANT2              Antlers        Antlers   3.0  WNW  Pushmataha
# 6       4  ANTL              Antlers        Antlers   5.0    W  Pushmataha
# 7     111  APAC               Apache         Apache   4.0  ENE       Caddo
# 8     126  ARD2              Ardmore        Ardmore   3.5  ENE      Carter
# 9       5  ARDM              Ardmore        Ardmore   3.0  ENE      Carter
# 10      6  ARNE               Arnett         Arnett   8.0  WSW       Ellis
# ...

# %%
site = "elre" # Watch out for upper and lower case. Code will not work if not lower case

# %%
df=weather.get_mesonet_dataframe(start_date,end_date,site)
df
# Out:
#      STID  STNM  TIME  RELH  TAIR  WSPD  WVEC   WDIR  WDSD  WSSD  \
# 0    ELRE    34     0  44.0  10.0   4.5   4.4  356.0   8.8   0.6
# 1    ELRE    34     5  45.0   9.8   4.4   4.3  357.0   8.6   0.5
# 2    ELRE    34    10  46.0   9.6   5.0   5.0    2.0   8.2   0.8
# 3    ELRE    34    15  47.0   9.4   5.2   5.2   13.0   8.1   0.8
# 4    ELRE    34    20  48.0   9.1   5.1   5.1   16.0   7.1   0.9
# 5    ELRE    34    25  50.0   8.6   4.9   4.9   12.0   7.1   0.8
# 6    ELRE    34    30  48.0   8.6   4.9   4.8   12.0   8.7   0.9
# 7    ELRE    34    35  48.0   8.3   5.0   4.9   12.0   7.9   1.0
# 8    ELRE    34    40  46.0   8.3   5.1   5.1    7.0   8.1   0.9
# 9    ELRE    34    45  46.0   7.8   4.7   4.7    8.0   8.4   1.0
# 10   ELRE    34    50  46.0   7.7   4.4   4.3    9.0   7.4   0.7
# 11   ELRE    34    55  45.0   7.6   4.9   4.9   12.0   5.8   0.8
# 12   ELRE    34    60  46.0   7.4   5.3   5.2   12.0   6.7   0.9
# ...

# %%
# Pandas Group By to get single day mean values
df.index=df.DATE
grp= df.groupby(['DATE']).mean()
grp['STID'] = "ELRE"
grp
# Out:
#             STNM   TIME       RELH       TAIR      WSPD      WVEC        WDIR  \
# DATE
# 2005-03-01  34.0  717.5  60.354167   2.153819  2.590972  2.548611   86.444444
# 2005-03-02  34.0  717.5  63.934028   5.698264  2.765972  2.721528  175.652778
# 2005-03-03  34.0  717.5  86.392361   8.310764  4.144097  4.107292  216.579861
# 2005-03-04  34.0  717.5  76.003472  11.544792  3.832292  3.780556  215.354167
# 2005-03-05  34.0  717.5  69.690972  12.221528  3.493403  3.452083  194.454861
# 2005-03-06  34.0  717.5  70.541667  12.681597  4.418750  4.384375  185.121528
# 2005-03-07  34.0  717.5  71.747082  13.714008  7.673541  7.592996  234.202335
# 2005-03-08  34.0  717.5  61.319149   6.491489  3.386111  3.339583  196.024306
# 2005-03-09  34.0  717.5  62.715278   8.857639  5.286458  5.224306  256.267361
# 2005-03-10  34.0  717.5  60.618056   8.431250  5.681597  5.620486  131.680556
# 2005-03-11  34.0  717.5  40.253472  11.074306  5.243056  5.199306  299.086806
# ...

# %% [markdown]
# ### Merge FLUX, MODIS, and OK Mesonet Data
#
# I realize that the datasets are not geographically coordinated. This does show the concept of merging data from multiple sources and perform inner join based on index.
#
# Help Merge http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html

# %%
mergedFrames = mdf.merge(grp,left_index=True,right_index=True)

# %%
mergedFrames
# Out:
#              GF_NDVI    GF_EVI     time  Ta_min (Deg C)  Ta_max (Deg C)  \
# 2005-03-06  0.494008  0.332621  2005065           -16.8             8.7
# 2005-03-14  0.453815  0.328477  2005073            -8.8             7.4
# 2005-03-22  0.513218  0.280360  2005081            -5.8             8.5
# 2005-03-30  0.637383  0.270904  2005089            -0.5            19.7
#
#             Ta_mean (Deg C)  Ta_daytime_mean (Deg C)  \
# 2005-03-06        -3.915625                -2.082812
# 2005-03-14        -0.018229                 2.140885
# 2005-03-22         1.980208                 3.777604
# 2005-03-30         6.443229                 9.396615
#
#             Ta_nighttime_mean(Deg C)     P_F  SW_IN_POT  ...       WS2M  \
# 2005-03-06                 -6.195313  5.4125   289.3965  ...   2.903472
# 2005-03-14                 -2.265365  0.0000   314.0216  ...   1.785069
# 2005-03-22                  0.046354  8.6000   338.3018  ...   6.549301
# ...
